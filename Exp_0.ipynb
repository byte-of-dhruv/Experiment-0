# %% [markdown]
# Exp 0 : Introduction to Python

# %%
#Dhruv Verulkar 25070123162
print("Dhruv Verulkar");
# Out:
# Dhruv Verulkar

# %%
print(2)
# Out:
# 2

# %%
print([1,2,5])
# Out:
# [1, 2, 5]

# %%
print([1, 2, 5])
print(2)
print("dhruv verulkar")
# Out:
# [1, 2, 5]
# 2
# dhruv verulkar

# %%
x=2
y=[1,2,5]
z = "Dhruv Verulkar"
print (x)
print(y)
print(z)
# Out:
# 2
# [1, 2, 5]
# Dhruv Verulkar

# %%
x=2
y=[1,2,5]
z = "Dhruv Verulkar"
print(x,y,z, sep="\n")
# Out:
# 2
# [1, 2, 5]
# Dhruv Verulkar
